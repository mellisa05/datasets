# %% [markdown]
# <a href="https://colab.research.google.com/github/mellisa05/datasets/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/mellisa05/datasets/main/games.csv")

# %%
df.head()
# Out:
#       Away_Team   Home_Team        Date        Ref_Crew  Accepted_Count  \
# 0     Tennessee  Pittsburgh  09/10/2009      Bill Leavy              11
# 1         Miami     Atlanta  09/13/2009    Walt Coleman               8
# 2   Kansas City   Baltimore  09/13/2009  Gene Steratore              11
# 3  Philadelphia    Carolina  09/13/2009  Jeff Triplette              14
# 4        Denver  Cincinnati  09/13/2009    Jerome Boger              10
#
#    Yards  Away_Count  Away_Yards  Home_Count  Home_Yards  Total_Flags  Week  \
# 0     88           5          28           6          60           13     1
# 1     62           4          27           4          35           11     1
# 2     80           3          15           8          65           14     1
# 3    106           9          76           5          30           14     1
# 4     66           6          39           4          27           12     1
#
#    Year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985',freq='D')

# %%
time_series_data = pd.Series(range(0,11))

# %%
df.head()
# Out:
#       Away_Team   Home_Team        Date        Ref_Crew  Accepted_Count  \
# 0     Tennessee  Pittsburgh  09/10/2009      Bill Leavy              11
# 1         Miami     Atlanta  09/13/2009    Walt Coleman               8
# 2   Kansas City   Baltimore  09/13/2009  Gene Steratore              11
# 3  Philadelphia    Carolina  09/13/2009  Jeff Triplette              14
# 4        Denver  Cincinnati  09/13/2009    Jerome Boger              10
#
#    Yards  Away_Count  Away_Yards  Home_Count  Home_Yards  Total_Flags  Week  \
# 0     88           5          28           6          60           13     1
# 1     62           4          27           4          35           11     1
# 2     80           3          15           8          65           14     1
# 3    106           9          76           5          30           14     1
# 4     66           6          39           4          27           12     1
#
#    Year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
date_rng = pd.date_range(start='01-01-1985',end='05-01-1985',freq='D')


time_series_data = pd.Series(range(0,11))


df
# Out:
#           Away_Team    Home_Team        Date        Ref_Crew  Accepted_Count  \
# 0         Tennessee   Pittsburgh  09/10/2009      Bill Leavy              11
# 1             Miami      Atlanta  09/13/2009    Walt Coleman               8
# 2       Kansas City    Baltimore  09/13/2009  Gene Steratore              11
# 3      Philadelphia     Carolina  09/13/2009  Jeff Triplette              14
# 4            Denver   Cincinnati  09/13/2009    Jerome Boger              10
# ...             ...          ...         ...             ...             ...
# 3577      Cleveland   Washington  01/01/2023   Bill Vinovich               8
# 3578  San Francisco    Las Vegas  01/01/2023     Clay Martin              15
# 3579      N.Y. Jets      Seattle  01/01/2023     Ron Torbert               7
# 3580      Minnesota    Green Bay  01/01/2023   Carl Cheffers               9
# 3581        LA Rams  LA Chargers  01/01/2023  Clete Blakeman               5
#
# ...

# %%
import matplotlib.pyplot as plt


time_series_data_trend = time_series_data + 0.5 * pd.Series(range(0,11))


df
# Out:
#           Away_Team    Home_Team        Date        Ref_Crew  Accepted_Count  \
# 0         Tennessee   Pittsburgh  09/10/2009      Bill Leavy              11
# 1             Miami      Atlanta  09/13/2009    Walt Coleman               8
# 2       Kansas City    Baltimore  09/13/2009  Gene Steratore              11
# 3      Philadelphia     Carolina  09/13/2009  Jeff Triplette              14
# 4            Denver   Cincinnati  09/13/2009    Jerome Boger              10
# ...             ...          ...         ...             ...             ...
# 3577      Cleveland   Washington  01/01/2023   Bill Vinovich               8
# 3578  San Francisco    Las Vegas  01/01/2023     Clay Martin              15
# 3579      N.Y. Jets      Seattle  01/01/2023     Ron Torbert               7
# 3580      Minnesota    Green Bay  01/01/2023   Carl Cheffers               9
# 3581        LA Rams  LA Chargers  01/01/2023  Clete Blakeman               5
#
# ...
